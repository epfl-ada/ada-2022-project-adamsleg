# %% [markdown]
# File name: main.ipynb
#
# Author: ADAMsLEG
#
# Date created: 03/11/2022
#
# Date last modified: 03/11/2022
#
# Python Version: 3.9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import json

# %%
DATA_PATH = "data/"

INTERVENTIONS_DATASET = DATA_PATH + "interventions.csv"
GLOBAL_MOBILITY_DATASET = DATA_PATH + "Global_Mobility_Report.csv.gz"
TOPICS_LINKED_DATASET = DATA_PATH + "topics_linked.csv.xz"
AGGREGATED_JSON = DATA_PATH + "aggregated_timeseries.json.gz"
COVIDISTRESS_APRIL = DATA_PATH + "COVIDISTRESS_april_cleaned.csv"
COVIDISTRESS_MAI = DATA_PATH + "COVIDISTRESS_mai_cleaned.csv"
COVIDISTRESS_JUNE = DATA_PATH + "COVIDISTRESS_june_cleaned.csv"

# %%
df_interventions = pd.read_csv(INTERVENTIONS_DATASET)
df_interventions.head()
# Out:
#   lang    1st case   1st death School closure Public events banned  \
# 0   fr  2020-01-24  2020-02-14     2020-03-14           2020-03-13
# 1   da  2020-02-27  2020-03-12     2020-03-13           2020-03-12
# 2   de  2020-01-27  2020-03-09     2020-03-14           2020-03-22
# 3   it  2020-01-31  2020-02-22     2020-03-05           2020-03-09
# 4   nl  2020-02-27  2020-03-06     2020-03-11           2020-03-24
#
#      Lockdown    Mobility    Normalcy
# 0  2020-03-17  2020-03-16  2020-07-02
# 1  2020-03-18  2020-03-11  2020-06-05
# 2  2020-03-22  2020-03-16  2020-07-10
# 3  2020-03-11  2020-03-11  2020-06-26
# 4         NaN  2020-03-16  2020-05-29

# %%
df_global = pd.read_csv(GLOBAL_MOBILITY_DATASET, compression='gzip')
df_global.head()
# Out:
# C:\Users\josan\AppData\Local\Temp\ipykernel_2304\3108490629.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_global = pd.read_csv(GLOBAL_MOBILITY_DATASET, compression='gzip')
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code        date  \
# 0        NaN             NaN               NaN  2020-02-15
# 1        NaN             NaN               NaN  2020-02-16
# 2        NaN             NaN               NaN  2020-02-17
# 3        NaN             NaN               NaN  2020-02-18
# 4        NaN             NaN               NaN  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                0.0
# 1                                                1.0
# 2                                               -1.0
# 3                                               -2.0
# 4                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
# 3                                            0.0
# 4                                           -1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
# 3                                      2.0
# 4                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %%
df_topics = pd.read_csv(TOPICS_LINKED_DATASET, compression='xz')
df_topics.head()
# Out:
#                    index  Geography.Regions.Asia.Central Asia  \
# 0               Rosmalen                                False
# 1           Commelinales                                False
# 2  Transport_in_Honduras                                False
# 3                 QuakeC                                False
# 4           Food_writing                                False
#
#    Geography.Regions.Europe.Eastern Europe  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    History and Society.Military and warfare  Culture.Media.Television  \
# 0                                     False                     False
# 1                                     False                     False
# 2                                     False                     False
# 3                                     False                     False
# 4                                     False                     False
#
#    History and Society.Education  Culture.Media.Books  \
# 0                          False                False
# 1                          False                False
# 2                          False                False
# 3                          False                False
# 4                          False                False
#
#    Geography.Regions.Africa.Africa*  Culture.Visual arts.Architecture  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    Culture.Biography.Women  ...  Geography.Regions.Asia.West Asia  \
# 0                    False  ...                             False
# 1                    False  ...                             False
# 2                    False  ...                             False
# 3                    False  ...                             False
# 4                    False  ...                             False
#
#    STEM.Chemistry  Geography.Regions.Europe.Northern Europe  \
# 0           False                                     False
# 1           False                                     False
# 2           False                                     False
# 3           False                                     False
# 4           False                                     False
#
#    Culture.Media.Video games  Geography.Regions.Asia.Southeast Asia  \
# 0                      False                                  False
# 1                      False                                  False
# 2                      False                                  False
# 3                      False                                  False
# 4                      False                                  False
#
#    Culture.Media.Entertainment  Culture.Media.Music  \
# 0                        False                False
# 1                        False                False
# 2                        False                False
# 3                        False                False
# 4                        False                False
#
#    Geography.Regions.Asia.Asia*  Geography.Regions.Asia.North Asia       qid
# 0                         False                              False  Q2001490
# 1                         False                              False   Q290349
# 2                         False                              False  Q1130638
# 3                         False                              False  Q2122062
# 4                         False                              False  Q5465542
#
# [5 rows x 66 columns]

# %%
ts_aggregated = pd.read_json(AGGREGATED_JSON, compression='gzip')
ts_aggregated.head()
# Out:
#                                                      ja.m  \
# len                                               1197788
# sum     {'2018-01-01 00:00:00': 22328288, '2018-01-02 ...
# covid   {'len': 30, 'sum': {'2018-01-01 00:00:00': 55,...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        it  \
# len                                               1594039
# sum     {'2018-01-01 00:00:00': 3338750, '2018-01-02 0...
# covid   {'len': 33, 'sum': {'2018-01-01 00:00:00': 50,...
# topics  {'Culture.Biography.Biography*': {'len': 29427...
#
#                                                      da.m  \
# len                                                256451
# sum     {'2018-01-01 00:00:00': 765123, '2018-01-02 00...
# covid   {'len': 4, 'sum': {'2018-01-01 00:00:00': 0, '...
# topics  {'Culture.Biography.Biography*': {'len': 57720...
#
#                                                        tr  \
# len                                                346007
# sum     {'2018-01-01 00:00:00': 407629, '2018-01-02 00...
# covid   {'len': 64, 'sum': {'2018-01-01 00:00:00': 1, ...
# topics  {'Culture.Biography.Biography*': {'len': 70443...
#
#                                                      no.m  \
# len                                                516838
# sum     {'2018-01-01 00:00:00': 715031, '2018-01-02 00...
# covid   {'len': 10, 'sum': {'2018-01-01 00:00:00': 7, ...
# topics  {'Culture.Biography.Biography*': {'len': 11603...
#
#                                                        en  \
# len                                               6047509
# sum     {'2018-01-01 00:00:00': 86763830, '2018-01-02 ...
# covid   {'len': 306, 'sum': {'2018-01-01 00:00:00': 57...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        sr  \
# len                                                632128
# sum     {'2018-01-01 00:00:00': 192409, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 6, '...
# topics  {'Culture.Biography.Biography*': {'len': 37718...
#
#                                                      tr.m  \
# len                                                345790
# sum     {'2018-01-01 00:00:00': 493684, '2018-01-02 00...
# covid   {'len': 64, 'sum': {'2018-01-01 00:00:00': 3, ...
# topics  {'Culture.Biography.Biography*': {'len': 70434...
#
#                                                      en.m  \
# len                                               6045654
# sum     {'2018-01-01 00:00:00': 135822131, '2018-01-02...
# covid   {'len': 306, 'sum': {'2018-01-01 00:00:00': 91...
# topics  {'Culture.Biography.Biography*': {'len': 14038...
#
#                                                        no  ...  \
# len                                                531478  ...
# sum     {'2018-01-01 00:00:00': 224417, '2018-01-02 00...  ...
# covid   {'len': 10, 'sum': {'2018-01-01 00:00:00': 2, ...  ...
# topics  {'Culture.Biography.Biography*': {'len': 11804...  ...
#
#                                                      ko.m  \
# len                                                489181
# sum     {'2018-01-01 00:00:00': 1484496, '2018-01-02 0...
# covid   {'len': 113, 'sum': {'2018-01-01 00:00:00': 6,...
# topics  {'Culture.Biography.Biography*': {'len': 75406...
#
#                                                      fi.m  \
# len                                                480638
# sum     {'2018-01-01 00:00:00': 1319053, '2018-01-02 0...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 0, '...
# topics  {'Culture.Biography.Biography*': {'len': 10422...
#
#                                                      sr.m  \
# len                                                396063
# sum     {'2018-01-01 00:00:00': 451383, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 11, ...
# topics  {'Culture.Biography.Biography*': {'len': 37580...
#
#                                                        ja  \
# len                                               1197856
# sum     {'2018-01-01 00:00:00': 7828155, '2018-01-02 0...
# covid   {'len': 30, 'sum': {'2018-01-01 00:00:00': 26,...
# topics  {'Culture.Biography.Biography*': {'len': 14904...
#
#                                                        fr  \
# len                                               2195949
# sum     {'2018-01-01 00:00:00': 6441009, '2018-01-02 0...
# covid   {'len': 16, 'sum': {'2018-01-01 00:00:00': 62,...
# topics  {'Culture.Biography.Biography*': {'len': 38258...
#
#                                                        fi  \
# len                                                481854
# sum     {'2018-01-01 00:00:00': 523135, '2018-01-02 00...
# covid   {'len': 9, 'sum': {'2018-01-01 00:00:00': 2, '...
# topics  {'Culture.Biography.Biography*': {'len': 10444...
#
#                                                        ca  \
# len                                                642031
# sum     {'2018-01-01 00:00:00': 111910, '2018-01-02 00...
# covid   {'len': 49, 'sum': {'2018-01-01 00:00:00': 6, ...
# topics  {'Culture.Biography.Biography*': {'len': 10175...
#
#                                                      it.m  \
# len                                               1588312
# sum     {'2018-01-01 00:00:00': 12856884, '2018-01-02 ...
# covid   {'len': 33, 'sum': {'2018-01-01 00:00:00': 139...
# topics  {'Culture.Biography.Biography*': {'len': 29422...
#
#                                                      sv.m  \
# len                                               1959446
# sum     {'2018-01-01 00:00:00': 2383474, '2018-01-02 0...
# covid   {'len': 8, 'sum': {'2018-01-01 00:00:00': 19, ...
# topics  {'Culture.Biography.Biography*': {'len': 14668...
#
#                                                        ko
# len                                                490314
# sum     {'2018-01-01 00:00:00': 819174, '2018-01-02 00...
# covid   {'len': 113, 'sum': {'2018-01-01 00:00:00': 3,...
# topics  {'Culture.Biography.Biography*': {'len': 75498...
#
# [4 rows x 28 columns]

# %%
df_anxiety_keyword = df_topics.loc[df_topics['index'].str.contains('anxiety').fillna(False)]
df_anxiety_keyword.head(5) #Social_anxiety is in the STEM.Medicine & Health topic,
# Out:
#                              index  Geography.Regions.Asia.Central Asia  \
# 29745               Social_anxiety                                False
# 100264          Intergroup_anxiety                                False
# 637466      Preoperational_anxiety                                False
# 805017             Library_anxiety                                False
# 853325  Separation_anxiety_in_dogs                                False
#
#         Geography.Regions.Europe.Eastern Europe  \
# 29745                                     False
# 100264                                    False
# 637466                                    False
# 805017                                    False
# 853325                                    False
#
#         History and Society.Military and warfare  Culture.Media.Television  \
# 29745                                      False                     False
# 100264                                     False                     False
# 637466                                     False                     False
# 805017                                     False                     False
# 853325                                     False                     False
#
#         History and Society.Education  Culture.Media.Books  \
# 29745                           False                False
# 100264                          False                False
# 637466                          False                False
# 805017                          False                False
# 853325                          False                False
#
#         Geography.Regions.Africa.Africa*  Culture.Visual arts.Architecture  \
# 29745                              False                             False
# 100264                             False                             False
# 637466                             False                             False
# 805017                             False                             False
# 853325                             False                             False
#
#         Culture.Biography.Women  ...  Geography.Regions.Asia.West Asia  \
# 29745                     False  ...                             False
# 100264                    False  ...                             False
# 637466                    False  ...                             False
# 805017                    False  ...                             False
# 853325                    False  ...                             False
#
#         STEM.Chemistry  Geography.Regions.Europe.Northern Europe  \
# 29745            False                                     False
# 100264           False                                     False
# 637466           False                                     False
# 805017           False                                     False
# 853325           False                                     False
#
#         Culture.Media.Video games  Geography.Regions.Asia.Southeast Asia  \
# 29745                       False                                  False
# 100264                      False                                  False
# 637466                      False                                  False
# 805017                      False                                  False
# 853325                      False                                  False
#
#         Culture.Media.Entertainment  Culture.Media.Music  \
# 29745                         False                False
# 100264                        False                False
# 637466                        False                False
# 805017                        False                False
# 853325                        False                False
#
#         Geography.Regions.Asia.Asia*  Geography.Regions.Asia.North Asia  \
# 29745                          False                              False
# 100264                         False                              False
# 637466                         False                              False
# 805017                         False                              False
# 853325                         False                              False
#
#              qid
# 29745   Q3557657
# 100264  Q6046586
# 637466  Q7240583
# 805017  Q6542544
# 853325  Q7451812
#
# [5 rows x 66 columns]

# %%
import gzip
data = [] #dict
with gzip.open(AGGREGATED_JSON, 'r') as fin:
    data = json.loads(fin.read().decode('utf-8'))

STEM_medicineandhealth = data["en"]["topics"]["STEM.Medicine & Health"] #more example on how to use in dataset description excel doc
pd.DataFrame.from_dict(STEM_medicineandhealth)
# Out:
#                        len      sum   percent
# 2018-01-01 00:00:00  63878  2207035  0.011472
# 2018-01-02 00:00:00  63878  3360222  0.012693
# 2018-01-03 00:00:00  63878  3648640  0.012824
# 2018-01-04 00:00:00  63878  3541603  0.013144
# 2018-01-05 00:00:00  63878  3357763  0.012822
# ...                    ...      ...       ...
# 2020-07-27 00:00:00  63878  2426547  0.011131
# 2020-07-28 00:00:00  63878  2442731  0.011610
# 2020-07-29 00:00:00  63878  2487592  0.012039
# 2020-07-30 00:00:00  63878  2297755  0.011380
# 2020-07-31 00:00:00  63878  2068595  0.011055
#
# [943 rows x 3 columns]

# %% [markdown]
# ### COVIDiSTRESS visualization

# %%
df_covidistress_april = pd.read_csv(COVIDISTRESS_APRIL)
df_covidistress_april.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Duration..in.seconds.         RecordedDate  \
# 0             0           1                   1058  2020-04-27 04:20:30
# 1             1           2                   1323  2020-04-27 04:17:16
# 2             2           3                    801  2020-04-27 04:05:14
#
#   UserLanguage  Dem_age Dem_gender                           Dem_edu  \
# 0           DA       33     Female  College degree, bachelor, master
# 1           NL       52       Male  College degree, bachelor, master
# 2           SK       52     Female  College degree, bachelor, master
#
#                   Dem_edu_mom      Dem_employment  ... Expl_media_6  \
# 0  Some College or equivalent  Full time employed  ...          3.0
# 1    Up to 12 years of school       Self-employed  ...          4.0
# 2              College degree  Full time employed  ...          4.0
#
#                                           Final_open PSS10_avg SLON3_avg  \
# 0                                                NaN       1.6  2.333333
# 1  Ik ben blij met de 'intelligente lockdown' zoa...       2.5  3.000000
# 2                                                NaN       2.4  3.666667
#
#         neu       ext       ope       agr       con   SPS_avg
# 0  2.000000  5.000000  4.666667  4.000000  3.666667  6.000000
# 1  4.666667  3.666667  5.000000  4.333333  4.666667  4.400000
# 2  3.000000  4.333333  4.333333  5.000000  4.666667  5.222222
#
# [3 rows x 137 columns]

# %%
df_covidistress_mai = pd.read_csv(COVIDISTRESS_MAI)
df_covidistress_mai.head(3)
# Out:
# C:\Users\josan\AppData\Local\Temp\ipykernel_2304\1816487094.py:1: DtypeWarning: Columns (56,57,58,59,60,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_covidistress_mai = pd.read_csv(COVIDISTRESS_MAI)
#    Unnamed: 0  ID answered_all  Duration..in.seconds.         RecordedDate  \
# 0           3   4           No                   1710  2020-05-29 22:47:17
# 1           5   6          Yes                   1221  2020-05-29 21:25:09
# 2          22  23          Yes                   1004  2020-05-29 18:03:27
#
#   UserLanguage  Dem_age Dem_gender                           Dem_edu  \
# 0           BG       79       Male  College degree, bachelor, master
# 1           IT       68       Male  College degree, bachelor, master
# 2           FR       28     Female                     PhD/Doctorate
#
#                Dem_edu_mom  ... Final_open PSS10_avg SLON3_avg       neu  \
# 0           College degree  ...        NaN       3.6  4.000000  4.000000
# 1           College degree  ...        NaN       2.1  2.333333  3.333333
# 2  Up to 9 years of school  ...        NaN       2.8  2.333333  4.666667
#
#         ext       ope       agr       con  SPS_avg  Scale_UCLA_TRI_avg
# 0  4.666667  4.000000  5.000000  5.000000      3.9                 NaN
# 1  3.666667  4.333333  4.000000  3.666667      5.0                 NaN
# 2  4.000000  5.333333  4.666667  3.333333      5.0                 NaN
#
# [3 rows x 155 columns]

# %%
df_covidistress_june = pd.read_csv(COVIDISTRESS_JUNE)
df_covidistress_june.head(3)
# Out:
# C:\Users\josan\AppData\Local\Temp\ipykernel_2304\883657938.py:1: DtypeWarning: Columns (55,56,57,58,59,60,61,66,67,68,69,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_covidistress_june = pd.read_csv(COVIDISTRESS_JUNE)
#    Unnamed: 0.1  Unnamed: 0  Duration..in.seconds.         RecordedDate  \
# 0             0           1                    777  2020-06-17 01:01:39
# 1             1           2                    952  2020-06-16 23:19:18
# 2             2           3                   2396  2020-06-16 22:47:36
#
#   UserLanguage  Dem_age Dem_gender                           Dem_edu  \
# 0           NL       48     Female  College degree, bachelor, master
# 1           PL       36     Female  College degree, bachelor, master
# 2           EN       45     Female  College degree, bachelor, master
#
#                 Dem_edu_mom      Dem_employment  ...  \
# 0                       NaN  Full time employed  ...
# 1  Up to 12 years of school  Full time employed  ...
# 2  Up to 12 years of school  Full time employed  ...
#
#                                           Final_open PSS10_avg SLON3_avg  \
# 0  Reguliere ziekenhuiszorg is verminderd: mijn c...       2.4  2.666667
# 1                                                NaN       1.7  1.000000
# 2                                                NaN       1.7  2.000000
#
#         neu       ext       ope       agr       con  SPS_avg  \
# 0  4.000000  3.666667  4.666667  4.333333  5.000000      5.1
# 1  2.333333  3.666667  3.000000  3.666667  4.666667      5.3
# 2  2.666667  4.333333  5.000000  5.000000  5.000000      5.2
#
#   Scale_UCLA_TRI_avg
# 0                NaN
# 1                NaN
# 2                NaN
#
# [3 rows x 154 columns]

# %%
MONTHS = ['june', 'mai', 'april']

fig, ax = plt.subplots(5, 5, figsize=(13, 12))

axes = ax.flatten()
for country, axe in zip(june_country.index, axes):
    df_hist_june = df_covidistress_june.loc[df_covidistress_june['Country'] == country]
    df_hist_mai = df_covidistress_mai.loc[df_covidistress_mai['Country'] == country]
    df_hist_april = df_covidistress_april.loc[df_covidistress_april['Country'] == country]
    
    axe.hist(df_hist_june['PSS10_avg'][:])
    axe.hist(df_hist_mai['PSS10_avg'][:], stacked=True, fill=False)
    axe.hist(df_hist_april['PSS10_avg'][:], alpha = .5)
    axe.set_yscale('log')
    axe.set_title(country)
    axe.legend(MONTHS)

fig.suptitle('PSS average accross 25 countries of Europe', fontsize=16)
fig.tight_layout()
fig.subplots_adjust(top=0.94)

# %%
fig, ax = plt.subplots(5, 5, figsize=(13, 12))

axes = ax.flatten()
for country, axe in zip(june_country.index, axes):
    df_hist_june = df_covidistress_june.loc[df_covidistress_june['Country'] == country]
    df_hist_mai = df_covidistress_mai.loc[df_covidistress_mai['Country'] == country]
    df_hist_april = df_covidistress_april.loc[df_covidistress_april['Country'] == country]
    
    axe.hist(df_hist_june['SLON3_avg'][:])
    axe.hist(df_hist_mai['SLON3_avg'][:], stacked=True, fill=False)
    axe.hist(df_hist_april['SLON3_avg'][:], alpha = .5)
    #axe.set_yscale('log')
    axe.set_title(country)
    axe.legend(MONTHS)

fig.suptitle('PSS average accross 25 countries of Europe', fontsize=16)
fig.tight_layout()
fig.subplots_adjust(top=0.94)

# %% [markdown]
# ## Dataset: Wikipedia:Pageview statistics

# %% [markdown]
# As we said in the Read.me, in order to analyze mental health awareness during Covid19, we decided to consider 5 mental disorders: anxiety, depression, loneliness, insomnia and physiological stress. For each of these diseases, we will use the number of Wikipedia page views about these diseases in the period 2019-01-01 - 2022-09-01. All data was downloaded from the website Wikipedia:Pageview statistics (https://pageviews.wmcloud.org/?project=en.wikipedia.org&platform=all-access&agent=user&redirects=0&range=latest-20&pages=).

# %% [markdown]
# Let's see what the data looks like

# %%
with open('{}.json'.format('./data/anxiety_en'), 'r') as file:
    data = json.load(file)[0]
data
# Out:
# {'page': 'Anxiety disorder',
#  'sum': 1991316,
#  'daily_average': 1454,
#  '2019-01-01': 1486,
#  '2019-01-02': 1842,
#  '2019-01-03': 1715,
#  '2019-01-04': 1724,
#  '2019-01-05': 1872,
#  '2019-01-06': 1771,
#  '2019-01-07': 1968,
#  '2019-01-08': 2027,
#  '2019-01-09': 2026,
#  '2019-01-10': 1840,
#  '2019-01-11': 1673,
#  '2019-01-12': 1533,
#  '2019-01-13': 1691,
#  '2019-01-14': 1890,
#  '2019-01-15': 1958,
#  '2019-01-16': 1916,
#  '2019-01-17': 1986,
#  '2019-01-18': 1896,
#  '2019-01-19': 1564,
#  '2019-01-20': 1780,
#  '2019-01-21': 1921,
#  '2019-01-22': 1972,
#  '2019-01-23': 1968,
#  '2019-01-24': 1905,
#  '2019-01-25': 1829,
#  '2019-01-26': 1641,
#  '2019-01-27': 1836,
#  '2019-01-28': 2032,
#  '2019-01-29': 2052,
#  '2019-01-30': 2147,
#  '2019-01-31': 2062,
#  '2019-02-01': 1711,
#  '2019-02-02': 1629,
#  '2019-02-03': 1737,
#  '2019-02-04': 2060,
#  '2019-02-05': 2065,
#  '2019-02-06': 1893,
#  '2019-02-07': 2074,
#  '2019-02-08': 1865,
#  '2019-02-09': 1827,
#  '2019-02-10': 1988,
#  '2019-02-11': 2640,
#  '2019-02-12': 2333,
#  '2019-02-13': 2171,
#  '2019-02-14': 2141,
#  '2019-02-15': 1835,
#  '2019-02-16': 2422,
#  '2019-02-17': 1905,
#  '2019-02-18': 2304,
#  '2019-02-19': 2224,
#  '2019-02-20': 2187,
#  '2019-02-21': 2073,
#  '2019-02-22': 1912,
#  '2019-02-23': 1763,
#  '2019-02-24': 1939,
#  '2019-02-25': 2369,
#  '2019-02-26': 2112,
#  '2019-02-27': 2163,
#  '2019-02-28': 2144,
#  '2019-03-01': 2066,
#  '2019-03-02': 1891,
#  '2019-03-03': 1980,
#  '2019-03-04': 2223,
#  '2019-03-05': 2189,
#  '2019-03-06': 2133,
#  '2019-03-07': 2091,
#  '2019-03-08': 2636,
#  '2019-03-09': 1685,
#  '2019-03-10': 1926,
#  '2019-03-11': 2181,
#  '2019-03-12': 1895,
#  '2019-03-13': 2131,
#  '2019-03-14': 2211,
#  '2019-03-15': 1929,
#  '2019-03-16': 1766,
#  '2019-03-17': 1858,
#  '2019-03-18': 2518,
#  '2019-03-19': 2600,
#  '2019-03-20': 2158,
#  '2019-03-21': 2108,
#  '2019-03-22': 1941,
#  '2019-03-23': 1706,
#  '2019-03-24': 1730,
#  '2019-03-25': 2146,
#  '2019-03-26': 2261,
#  '2019-03-27': 2243,
#  '2019-03-28': 2019,
#  '2019-03-29': 2073,
#  '2019-03-30': 1623,
#  '2019-03-31': 1968,
#  '2019-04-01': 2683,
#  '2019-04-02': 2170,
#  '2019-04-03': 2217,
#  '2019-04-04': 2230,
#  '2019-04-05': 2037,
#  '2019-04-06': 1729,
#  '2019-04-07': 1788,
#  '2019-04-08': 1958,
#  '2019-04-09': 2197,
#  '2019-04-10': 2219,
#  '2019-04-11': 2170,
#  '2019-04-12': 1971,
#  '2019-04-13': 1725,
#  '2019-04-14': 2100,
#  '2019-04-15': 2421,
#  '2019-04-16': 2252,
#  '2019-04-17': 2339,
#  '2019-04-18': 2089,
#  '2019-04-19': 1934,
#  '2019-04-20': 1718,
#  '2019-04-21': 1897,
#  '2019-04-22': 2488,
#  '2019-04-23': 2311,
#  '2019-04-24': 2296,
#  '2019-04-25': 2855,
#  '2019-04-26': 2312,
#  '2019-04-27': 1799,
#  '2019-04-28': 2037,
#  '2019-04-29': 2639,
#  '2019-04-30': 2406,
#  '2019-05-01': 2367,
#  '2019-05-02': 2498,
#  '2019-05-03': 2416,
#  '2019-05-04': 1885,
#  '2019-05-05': 2302,
#  '2019-05-06': 2666,
#  '2019-05-07': 2540,
#  '2019-05-08': 2378,
#  '2019-05-09': 2311,
#  '2019-05-10': 2036,
#  '2019-05-11': 1792,
#  '2019-05-12': 1729,
#  '2019-05-13': 2188,
#  '2019-05-14': 2340,
#  '2019-05-15': 2197,
#  '2019-05-16': 2132,
#  '2019-05-17': 1781,
#  '2019-05-18': 1606,
#  '2019-05-19': 2179,
#  '2019-05-20': 1999,
#  '2019-05-21': 1992,
#  '2019-05-22': 2030,
#  '2019-05-23': 1932,
#  '2019-05-24': 1757,
#  '2019-05-25': 1494,
#  '2019-05-26': 1728,
#  '2019-05-27': 1992,
#  '2019-05-28': 2031,
#  '2019-05-29': 1844,
#  '2019-05-30': 1999,
#  '2019-05-31': 1817,
#  '2019-06-01': 1462,
#  '2019-06-02': 1506,
#  '2019-06-03': 1855,
#  '2019-06-04': 1817,
#  '2019-06-05': 1849,
#  '2019-06-06': 1812,
#  '2019-06-07': 1688,
#  '2019-06-08': 1495,
#  '2019-06-09': 1717,
#  '2019-06-10': 2031,
#  '2019-06-11': 1898,
#  '2019-06-12': 2000,
#  '2019-06-13': 1845,
#  '2019-06-14': 1734,
#  '2019-06-15': 1559,
#  '2019-06-16': 1726,
#  '2019-06-17': 1917,
#  '2019-06-18': 1917,
#  '2019-06-19': 1991,
#  '2019-06-20': 1807,
#  '2019-06-21': 1866,
#  '2019-06-22': 1866,
#  '2019-06-23': 2046,
#  '2019-06-24': 2294,
#  '2019-06-25': 2699,
#  '2019-06-26': 2190,
#  '2019-06-27': 2000,
#  '2019-06-28': 1789,
#  '2019-06-29': 1486,
#  '2019-06-30': 1773,
#  '2019-07-01': 1841,
#  '2019-07-02': 1961,
#  '2019-07-03': 1703,
#  '2019-07-04': 1615,
#  '2019-07-05': 1650,
#  '2019-07-06': 1744,
#  '2019-07-07': 1856,
#  '2019-07-08': 1971,
#  '2019-07-09': 2061,
#  '2019-07-10': 1987,
#  '2019-07-11': 2025,
#  '2019-07-12': 2010,
#  '2019-07-13': 1672,
#  '2019-07-14': 1813,
#  '2019-07-15': 2120,
#  '2019-07-16': 1985,
#  '2019-07-17': 1905,
#  '2019-07-18': 1902,
#  '2019-07-19': 1673,
#  '2019-07-20': 1515,
#  '2019-07-21': 1763,
#  '2019-07-22': 1865,
#  '2019-07-23': 1910,
#  '2019-07-24': 1901,
#  '2019-07-25': 1840,
#  '2019-07-26': 2102,
#  '2019-07-27': 1457,
#  '2019-07-28': 1823,
#  '2019-07-29': 2063,
#  '2019-07-30': 1987,
#  '2019-07-31': 1934,
#  '2019-08-01': 2022,
#  '2019-08-02': 1740,
#  '2019-08-03': 1621,
#  '2019-08-04': 1714,
#  '2019-08-05': 1911,
#  '2019-08-06': 1929,
#  '2019-08-07': 1790,
#  '2019-08-08': 1756,
#  '2019-08-09': 1700,
#  '2019-08-10': 1581,
#  '2019-08-11': 1561,
#  '2019-08-12': 1777,
#  '2019-08-13': 1722,
#  '2019-08-14': 1910,
#  '2019-08-15': 1686,
#  '2019-08-16': 2436,
#  '2019-08-17': 1493,
#  '2019-08-18': 1768,
#  '2019-08-19': 1864,
#  '2019-08-20': 1800,
#  '2019-08-21': 1723,
#  '2019-08-22': 1653,
#  '2019-08-23': 1496,
#  '2019-08-24': 1462,
#  '2019-08-25': 1497,
#  '2019-08-26': 1754,
#  '2019-08-27': 3756,
#  '2019-08-28': 2313,
#  '2019-08-29': 2397,
#  '2019-08-30': 1786,
#  '2019-08-31': 1674,
#  '2019-09-01': 1802,
#  '2019-09-02': 1826,
#  '2019-09-03': 1840,
#  '2019-09-04': 1928,
#  '2019-09-05': 1687,
#  '2019-09-06': 1436,
#  '2019-09-07': 1427,
#  '2019-09-08': 1645,
#  '2019-09-09': 1903,
#  '2019-09-10': 1805,
#  '2019-09-11': 1898,
#  '2019-09-12': 1932,
#  '2019-09-13': 1688,
#  '2019-09-14': 1598,
#  '2019-09-15': 1844,
#  '2019-09-16': 1949,
#  '2019-09-17': 1929,
#  '2019-09-18': 1903,
#  '2019-09-19': 1804,
#  '2019-09-20': 1562,
#  '2019-09-21': 1545,
#  '2019-09-22': 1776,
#  '2019-09-23': 2081,
#  '2019-09-24': 2037,
#  '2019-09-25': 1998,
#  '2019-09-26': 2049,
#  '2019-09-27': 1794,
#  '2019-09-28': 1639,
#  '2019-09-29': 1784,
#  '2019-09-30': 2258,
#  '2019-10-01': 1986,
#  '2019-10-02': 2038,
#  '2019-10-03': 1922,
#  '2019-10-04': 1799,
#  '2019-10-05': 1736,
#  '2019-10-06': 1835,
#  '2019-10-07': 2166,
#  '2019-10-08': 2052,
#  '2019-10-09': 2020,
#  '2019-10-10': 2121,
#  '2019-10-11': 1980,
#  '2019-10-12': 1654,
#  '2019-10-13': 1819,
#  '2019-10-14': 2182,
#  '2019-10-15': 2172,
#  '2019-10-16': 1982,
#  '2019-10-17': 2026,
#  '2019-10-18': 2085,
#  '2019-10-19': 2111,
#  '2019-10-20': 2236,
#  '2019-10-21': 2485,
#  '2019-10-22': 2038,
#  '2019-10-23': 2101,
#  '2019-10-24': 1962,
#  '2019-10-25': 1683,
#  '2019-10-26': 1664,
#  '2019-10-27': 1762,
#  '2019-10-28': 2142,
#  '2019-10-29': 2041,
#  '2019-10-30': 2027,
#  '2019-10-31': 1771,
#  '2019-11-01': 1751,
#  '2019-11-02': 1569,
#  '2019-11-03': 1782,
#  '2019-11-04': 2087,
#  '2019-11-05': 2055,
#  '2019-11-06': 1933,
#  '2019-11-07': 2010,
#  '2019-11-08': 1693,
#  '2019-11-09': 1683,
#  '2019-11-10': 1784,
#  '2019-11-11': 2154,
#  '2019-11-12': 2528,
#  '2019-11-13': 2092,
#  '2019-11-14': 2107,
#  '2019-11-15': 1697,
#  '2019-11-16': 1435,
#  '2019-11-17': 1711,
#  '2019-11-18': 2017,
#  '2019-11-19': 1954,
#  '2019-11-20': 1922,
#  '2019-11-21': 1772,
#  '2019-11-22': 1546,
#  '2019-11-23': 1495,
#  '2019-11-24': 1777,
#  '2019-11-25': 1923,
#  '2019-11-26': 1905,
#  '2019-11-27': 1933,
#  '2019-11-28': 1740,
#  '2019-11-29': 1550,
#  '2019-11-30': 1546,
#  '2019-12-01': 1691,
#  '2019-12-02': 2386,
#  '2019-12-03': 1868,
#  '2019-12-04': 1795,
#  '2019-12-05': 1772,
#  '2019-12-06': 1567,
#  '2019-12-07': 1501,
#  '2019-12-08': 1705,
#  '2019-12-09': 1972,
#  '2019-12-10': 2008,
#  '2019-12-11': 2464,
#  '2019-12-12': 1920,
#  '2019-12-13': 1718,
#  '2019-12-14': 1560,
#  '2019-12-15': 1681,
#  '2019-12-16': 1980,
#  '2019-12-17': 2408,
#  '2019-12-18': 1919,
#  '2019-12-19': 1676,
#  '2019-12-20': 1343,
#  '2019-12-21': 1324,
#  '2019-12-22': 1297,
#  '2019-12-23': 1396,
#  '2019-12-24': 1256,
#  '2019-12-25': 1192,
#  '2019-12-26': 1399,
#  '2019-12-27': 1542,
#  '2019-12-28': 1430,
#  '2019-12-29': 1523,
#  '2019-12-30': 1581,
#  '2019-12-31': 1378,
#  '2020-01-01': 1422,
#  '2020-01-02': 1856,
#  '2020-01-03': 1669,
#  '2020-01-04': 1601,
#  '2020-01-05': 1757,
#  '2020-01-06': 1893,
#  '2020-01-07': 1975,
#  '2020-01-08': 2011,
#  '2020-01-09': 1860,
#  '2020-01-10': 1778,
#  '2020-01-11': 1645,
#  '2020-01-12': 1948,
#  '2020-01-13': 1953,
#  '2020-01-14': 2006,
#  '2020-01-15': 2022,
#  '2020-01-16': 1902,
#  '2020-01-17': 1735,
#  '2020-01-18': 1669,
#  '2020-01-19': 1775,
#  '2020-01-20': 1893,
#  '2020-01-21': 2105,
#  '2020-01-22': 2036,
#  '2020-01-23': 1889,
#  '2020-01-24': 1747,
#  '2020-01-25': 1639,
#  '2020-01-26': 1703,
#  '2020-01-27': 1926,
#  '2020-01-28': 1937,
#  '2020-01-29': 1944,
#  '2020-01-30': 1890,
#  '2020-01-31': 1731,
#  '2020-02-01': 1493,
#  '2020-02-02': 1627,
#  '2020-02-03': 1943,
#  '2020-02-04': 1941,
#  '2020-02-05': 1854,
#  '2020-02-06': 1894,
#  '2020-02-07': 1838,
#  '2020-02-08': 1595,
#  '2020-02-09': 1793,
#  '2020-02-10': 2127,
#  '2020-02-11': 2109,
#  '2020-02-12': 1959,
#  '2020-02-13': 1904,
#  '2020-02-14': 1635,
#  '2020-02-15': 1689,
#  '2020-02-16': 1837,
#  '2020-02-17': 1979,
#  '2020-02-18': 2033,
#  '2020-02-19': 2055,
#  '2020-02-20': 1884,
#  '2020-02-21': 1667,
#  '2020-02-22': 1616,
#  '2020-02-23': 1808,
#  '2020-02-24': 1914,
#  '2020-02-25': 2059,
#  '2020-02-26': 2129,
#  '2020-02-27': 1914,
#  '2020-02-28': 1672,
#  '2020-02-29': 1577,
#  '2020-03-01': 1783,
#  '2020-03-02': 1927,
#  '2020-03-03': 2050,
#  '2020-03-04': 1962,
#  '2020-03-05': 1820,
#  '2020-03-06': 1681,
#  '2020-03-07': 1586,
#  '2020-03-08': 1736,
#  '2020-03-09': 1866,
#  '2020-03-10': 2116,
#  '2020-03-11': 1919,
#  '2020-03-12': 1670,
#  '2020-03-13': 1473,
#  '2020-03-14': 1359,
#  '2020-03-15': 1473,
#  '2020-03-16': 1470,
#  '2020-03-17': 1550,
#  '2020-03-18': 1490,
#  '2020-03-19': 1525,
#  '2020-03-20': 1433,
#  '2020-03-21': 1453,
#  '2020-03-22': 1444,
#  '2020-03-23': 1659,
#  '2020-03-24': 1687,
#  '2020-03-25': 1687,
#  '2020-03-26': 1601,
#  '2020-03-27': 1558,
#  '2020-03-28': 1645,
#  '2020-03-29': 1678,
#  '2020-03-30': 1838,
#  '2020-03-31': 1897,
#  '2020-04-01': 1662,
#  '2020-04-02': 1691,
#  '2020-04-03': 1627,
#  '2020-04-04': 1594,
#  '2020-04-05': 1727,
#  '2020-04-06': 1764,
#  '2020-04-07': 2230,
#  '2020-04-08': 1766,
#  '2020-04-09': 1759,
#  '2020-04-10': 1803,
#  '2020-04-11': 1710,
#  '2020-04-12': 1739,
#  '2020-04-13': 1796,
#  '2020-04-14': 1927,
#  '2020-04-15': 1884,
#  '2020-04-16': 2244,
#  '2020-04-17': 1921,
#  '2020-04-18': 1713,
#  '2020-04-19': 1919,
#  '2020-04-20': 1975,
#  '2020-04-21': 1934,
#  '2020-04-22': 2004,
#  '2020-04-23': 2129,
#  '2020-04-24': 1886,
#  '2020-04-25': 1792,
#  '2020-04-26': 1844,
#  '2020-04-27': 1973,
#  '2020-04-28': 1925,
#  '2020-04-29': 1861,
#  '2020-04-30': 1835,
#  '2020-05-01': 1550,
#  '2020-05-02': 1504,
#  '2020-05-03': 1694,
#  '2020-05-04': 1809,
#  '2020-05-05': 1697,
#  '2020-05-06': 1611,
#  '2020-05-07': 1534,
#  '2020-05-08': 1457,
#  '2020-05-09': 1418,
#  '2020-05-10': 1396,
#  '2020-05-11': 1638,
#  '2020-05-12': 1636,
#  '2020-05-13': 1616,
#  '2020-05-14': 2376,
#  '2020-05-15': 1727,
#  '2020-05-16': 1695,
#  '2020-05-17': 1538,
#  '2020-05-18': 1613,
#  '2020-05-19': 1600,
#  '2020-05-20': 1593,
#  '2020-05-21': 1522,
#  '2020-05-22': 1382,
#  '2020-05-23': 1435,
#  '2020-05-24': 1531,
#  '2020-05-25': 1535,
#  '2020-05-26': 1567,
#  '2020-05-27': 1594,
#  '2020-05-28': 1630,
#  '2020-05-29': 1422,
#  '2020-05-30': 1296,
#  '2020-05-31': 1370,
#  '2020-06-01': 1498,
#  '2020-06-02': 1408,
#  '2020-06-03': 1361,
#  '2020-06-04': 1294,
#  '2020-06-05': 1293,
#  '2020-06-06': 1192,
#  '2020-06-07': 1249,
#  '2020-06-08': 1382,
#  '2020-06-09': 1410,
#  '2020-06-10': 1512,
#  '2020-06-11': 1332,
#  '2020-06-12': 1352,
#  '2020-06-13': 1206,
#  '2020-06-14': 1417,
#  '2020-06-15': 1543,
#  '2020-06-16': 1456,
#  '2020-06-17': 1402,
#  '2020-06-18': 1390,
#  '2020-06-19': 1363,
#  '2020-06-20': 1326,
#  '2020-06-21': 1553,
#  '2020-06-22': 1573,
#  '2020-06-23': 1456,
#  '2020-06-24': 1473,
#  '2020-06-25': 1428,
#  '2020-06-26': 1457,
#  '2020-06-27': 1330,
#  '2020-06-28': 1304,
#  '2020-06-29': 1377,
#  '2020-06-30': 1362,
#  '2020-07-01': 1299,
#  '2020-07-02': 1303,
#  '2020-07-03': 1218,
#  '2020-07-04': 1169,
#  '2020-07-05': 1323,
#  '2020-07-06': 1385,
#  '2020-07-07': 1308,
#  '2020-07-08': 1442,
#  '2020-07-09': 1445,
#  '2020-07-10': 1299,
#  '2020-07-11': 1212,
#  '2020-07-12': 1244,
#  '2020-07-13': 1351,
#  '2020-07-14': 1441,
#  '2020-07-15': 1814,
#  '2020-07-16': 1333,
#  '2020-07-17': 1347,
#  '2020-07-18': 1289,
#  '2020-07-19': 1313,
#  '2020-07-20': 1525,
#  '2020-07-21': 1529,
#  '2020-07-22': 1457,
#  '2020-07-23': 1414,
#  '2020-07-24': 1383,
#  '2020-07-25': 1277,
#  '2020-07-26': 1386,
#  '2020-07-27': 1424,
#  '2020-07-28': 1425,
#  '2020-07-29': 1387,
#  '2020-07-30': 1289,
#  '2020-07-31': 1221,
#  '2020-08-01': 1204,
#  '2020-08-02': 1295,
#  '2020-08-03': 1323,
#  '2020-08-04': 1390,
#  '2020-08-05': 1270,
#  '2020-08-06': 1464,
#  '2020-08-07': 1240,
#  '2020-08-08': 1326,
#  '2020-08-09': 1308,
#  '2020-08-10': 1557,
#  '2020-08-11': 2025,
#  '2020-08-12': 1393,
#  '2020-08-13': 1377,
#  '2020-08-14': 1377,
#  '2020-08-15': 1318,
#  '2020-08-16': 1307,
#  '2020-08-17': 1550,
#  '2020-08-18': 1476,
#  '2020-08-19': 1474,
#  '2020-08-20': 1382,
#  '2020-08-21': 1324,
#  '2020-08-22': 1213,
#  '2020-08-23': 1279,
#  '2020-08-24': 1379,
#  '2020-08-25': 1356,
#  '2020-08-26': 1352,
#  '2020-08-27': 1816,
#  '2020-08-28': 1446,
#  '2020-08-29': 1390,
#  '2020-08-30': 1311,
#  '2020-08-31': 1412,
#  '2020-09-01': 1354,
#  '2020-09-02': 1345,
#  '2020-09-03': 1335,
#  '2020-09-04': 1290,
#  '2020-09-05': 1156,
#  '2020-09-06': 1383,
#  '2020-09-07': 1376,
#  '2020-09-08': 1427,
#  '2020-09-09': 1377,
#  '2020-09-10': 1376,
#  '2020-09-11': 1255,
#  '2020-09-12': 1285,
#  '2020-09-13': 1364,
#  '2020-09-14': 1448,
#  '2020-09-15': 1473,
#  '2020-09-16': 1436,
#  '2020-09-17': 1254,
#  '2020-09-18': 1344,
#  '2020-09-19': 1195,
#  '2020-09-20': 1278,
#  '2020-09-21': 1490,
#  '2020-09-22': 1457,
#  '2020-09-23': 1379,
#  '2020-09-24': 1436,
#  '2020-09-25': 1374,
#  '2020-09-26': 1314,
#  '2020-09-27': 1421,
#  '2020-09-28': 1476,
#  '2020-09-29': 1547,
#  '2020-09-30': 1387,
#  '2020-10-01': 1492,
#  '2020-10-02': 1344,
#  '2020-10-03': 1292,
#  '2020-10-04': 1348,
#  '2020-10-05': 1611,
#  '2020-10-06': 1566,
#  '2020-10-07': 1513,
#  '2020-10-08': 1555,
#  '2020-10-09': 1428,
#  '2020-10-10': 1378,
#  '2020-10-11': 1506,
#  '2020-10-12': 1519,
#  '2020-10-13': 1593,
#  '2020-10-14': 1546,
#  '2020-10-15': 1605,
#  '2020-10-16': 1415,
#  '2020-10-17': 1247,
#  '2020-10-18': 1333,
#  '2020-10-19': 1551,
#  '2020-10-20': 1617,
#  '2020-10-21': 1526,
#  '2020-10-22': 1388,
#  '2020-10-23': 1368,
#  '2020-10-24': 1243,
#  '2020-10-25': 1351,
#  '2020-10-26': 1408,
#  '2020-10-27': 1526,
#  '2020-10-28': 1442,
#  '2020-10-29': 1490,
#  '2020-10-30': 1372,
#  '2020-10-31': 1231,
#  '2020-11-01': 1327,
#  '2020-11-02': 1499,
#  '2020-11-03': 1443,
#  '2020-11-04': 1323,
#  '2020-11-05': 1433,
#  '2020-11-06': 1309,
#  '2020-11-07': 1254,
#  '2020-11-08': 1166,
#  '2020-11-09': 1471,
#  '2020-11-10': 1565,
#  '2020-11-11': 1614,
#  '2020-11-12': 1581,
#  '2020-11-13': 1417,
#  '2020-11-14': 1278,
#  '2020-11-15': 1424,
#  '2020-11-16': 1625,
#  '2020-11-17': 1609,
#  '2020-11-18': 1676,
#  '2020-11-19': 1569,
#  '2020-11-20': 1502,
#  '2020-11-21': 1337,
#  '2020-11-22': 1388,
#  '2020-11-23': 1600,
#  '2020-11-24': 1596,
#  '2020-11-25': 1496,
#  '2020-11-26': 1462,
#  '2020-11-27': 1347,
#  '2020-11-28': 1308,
#  '2020-11-29': 1431,
#  '2020-11-30': 1574,
#  '2020-12-01': 1565,
#  '2020-12-02': 1586,
#  '2020-12-03': 1585,
#  '2020-12-04': 1465,
#  '2020-12-05': 1353,
#  '2020-12-06': 1421,
#  '2020-12-07': 1507,
#  '2020-12-08': 1541,
#  '2020-12-09': 1592,
#  '2020-12-10': 1525,
#  '2020-12-11': 1282,
#  '2020-12-12': 1222,
#  '2020-12-13': 1334,
#  '2020-12-14': 1548,
#  '2020-12-15': 1534,
#  '2020-12-16': 1473,
#  '2020-12-17': 1443,
#  '2020-12-18': 1275,
#  '2020-12-19': 1227,
#  '2020-12-20': 1266,
#  '2020-12-21': 1381,
#  '2020-12-22': 1351,
#  '2020-12-23': 1251,
#  '2020-12-24': 1150,
#  '2020-12-25': 1019,
#  '2020-12-26': 1121,
#  '2020-12-27': 1238,
#  '2020-12-28': 1339,
#  '2020-12-29': 1309,
#  '2020-12-30': 1383,
#  '2020-12-31': 1129,
#  '2021-01-01': 1139,
#  '2021-01-02': 1323,
#  '2021-01-03': 1442,
#  '2021-01-04': 1615,
#  '2021-01-05': 1460,
#  '2021-01-06': 1416,
#  '2021-01-07': 1323,
#  '2021-01-08': 1326,
#  '2021-01-09': 1219,
#  '2021-01-10': 1332,
#  '2021-01-11': 1600,
#  '2021-01-12': 1542,
#  '2021-01-13': 1390,
#  '2021-01-14': 1336,
#  '2021-01-15': 1322,
#  '2021-01-16': 1276,
#  '2021-01-17': 1296,
#  '2021-01-18': 1416,
#  '2021-01-19': 1441,
#  '2021-01-20': 1305,
#  '2021-01-21': 1400,
#  '2021-01-22': 1422,
#  '2021-01-23': 1295,
#  '2021-01-24': 1348,
#  '2021-01-25': 1519,
#  '2021-01-26': 1462,
#  '2021-01-27': 1496,
#  '2021-01-28': 1446,
#  '2021-01-29': 1350,
#  '2021-01-30': 1256,
#  '2021-01-31': 1369,
#  '2021-02-01': 1508,
#  '2021-02-02': 1399,
#  '2021-02-03': 1446,
#  '2021-02-04': 1398,
#  '2021-02-05': 1354,
#  '2021-02-06': 1230,
#  '2021-02-07': 1326,
#  '2021-02-08': 1394,
#  '2021-02-09': 1477,
#  '2021-02-10': 1344,
#  '2021-02-11': 1394,
#  '2021-02-12': 1288,
#  '2021-02-13': 1134,
#  '2021-02-14': 1300,
#  '2021-02-15': 1366,
#  '2021-02-16': 1504,
#  '2021-02-17': 1439,
#  '2021-02-18': 1396,
#  '2021-02-19': 1273,
#  '2021-02-20': 1246,
#  '2021-02-21': 1411,
#  '2021-02-22': 1493,
#  '2021-02-23': 1509,
#  '2021-02-24': 1548,
#  '2021-02-25': 1560,
#  '2021-02-26': 1450,
#  '2021-02-27': 1274,
#  '2021-02-28': 1529,
#  '2021-03-01': 1650,
#  '2021-03-02': 1627,
#  '2021-03-03': 1540,
#  '2021-03-04': 1475,
#  '2021-03-05': 1524,
#  '2021-03-06': 1473,
#  '2021-03-07': 1486,
#  '2021-03-08': 1556,
#  '2021-03-09': 1528,
#  '2021-03-10': 1559,
#  '2021-03-11': 1644,
#  '2021-03-12': 1507,
#  '2021-03-13': 1325,
#  '2021-03-14': 1494,
#  '2021-03-15': 1562,
#  '2021-03-16': 1593,
#  '2021-03-17': 1519,
#  '2021-03-18': 1525,
#  '2021-03-19': 1335,
#  '2021-03-20': 1376,
#  '2021-03-21': 1362,
#  '2021-03-22': 1612,
#  '2021-03-23': 1594,
#  '2021-03-24': 1587,
#  '2021-03-25': 1654,
#  '2021-03-26': 1498,
#  '2021-03-27': 1311,
#  '2021-03-28': 1415,
#  '2021-03-29': 1497,
#  '2021-03-30': 1508,
#  '2021-03-31': 1479,
#  '2021-04-01': 1328,
#  '2021-04-02': 1224,
#  '2021-04-03': 1217,
#  '2021-04-04': 1374,
#  '2021-04-05': 1493,
#  '2021-04-06': 1534,
#  '2021-04-07': 1553,
#  '2021-04-08': 1505,
#  '2021-04-09': 1446,
#  '2021-04-10': 1401,
#  '2021-04-11': 1413,
#  '2021-04-12': 1622,
#  '2021-04-13': 1554,
#  '2021-04-14': 1464,
#  '2021-04-15': 1483,
#  '2021-04-16': 1490,
#  '2021-04-17': 1307,
#  '2021-04-18': 1335,
#  '2021-04-19': 1563,
#  '2021-04-20': 1507,
#  '2021-04-21': 1471,
#  '2021-04-22': 1383,
#  '2021-04-23': 1316,
#  '2021-04-24': 1205,
#  '2021-04-25': 1399,
#  '2021-04-26': 1499,
#  '2021-04-27': 1458,
#  '2021-04-28': 1373,
#  '2021-04-29': 1408,
#  '2021-04-30': 1426,
#  '2021-05-01': 1198,
#  '2021-05-02': 1258,
#  '2021-05-03': 1509,
#  '2021-05-04': 1503,
#  '2021-05-05': 1564,
#  '2021-05-06': 1471,
#  '2021-05-07': 1309,
#  '2021-05-08': 1200,
#  '2021-05-09': 1306,
#  '2021-05-10': 1527,
#  '2021-05-11': 1464,
#  '2021-05-12': 1439,
#  '2021-05-13': 1302,
#  '2021-05-14': 1296,
#  '2021-05-15': 1366,
#  '2021-05-16': 1342,
#  '2021-05-17': 1606,
#  '2021-05-18': 1492,
#  '2021-05-19': 1470,
#  '2021-05-20': 1428,
#  '2021-05-21': 1366,
#  '2021-05-22': 1249,
#  '2021-05-23': 1359,
#  '2021-05-24': 1447,
#  '2021-05-25': 1460,
#  '2021-05-26': 1485,
#  '2021-05-27': 1458,
#  '2021-05-28': 1325,
#  '2021-05-29': 1230,
#  '2021-05-30': 1331,
#  '2021-05-31': 1420,
#  '2021-06-01': 1467,
#  '2021-06-02': 1389,
#  '2021-06-03': 1365,
#  '2021-06-04': 1399,
#  '2021-06-05': 1232,
#  '2021-06-06': 1427,
#  '2021-06-07': 1442,
#  '2021-06-08': 1534,
#  '2021-06-09': 1494,
#  '2021-06-10': 1429,
#  '2021-06-11': 1225,
#  '2021-06-12': 1316,
#  '2021-06-13': 1253,
#  '2021-06-14': 1371,
#  '2021-06-15': 1270,
#  '2021-06-16': 1286,
#  '2021-06-17': 1201,
#  '2021-06-18': 1295,
#  '2021-06-19': 1234,
#  '2021-06-20': 1292,
#  '2021-06-21': 1402,
#  '2021-06-22': 1313,
#  '2021-06-23': 1273,
#  '2021-06-24': 1223,
#  '2021-06-25': 1253,
#  '2021-06-26': 1070,
#  '2021-06-27': 1228,
#  '2021-06-28': 1328,
#  '2021-06-29': 1257,
#  '2021-06-30': 1288,
#  '2021-07-01': 1296,
#  '2021-07-02': 1158,
#  '2021-07-03': 1115,
#  '2021-07-04': 1221,
#  '2021-07-05': 1231,
#  '2021-07-06': 1306,
#  '2021-07-07': 1257,
#  '2021-07-08': 1193,
#  '2021-07-09': 1186,
#  '2021-07-10': 1131,
#  '2021-07-11': 1123,
#  '2021-07-12': 1253,
#  '2021-07-13': 1144,
#  '2021-07-14': 1106,
#  '2021-07-15': 1076,
#  '2021-07-16': 943,
#  '2021-07-17': 972,
#  '2021-07-18': 1031,
#  '2021-07-19': 1025,
#  '2021-07-20': 1090,
#  '2021-07-21': 1020,
#  '2021-07-22': 1039,
#  '2021-07-23': 1015,
#  '2021-07-24': 1028,
#  '2021-07-25': 1093,
#  '2021-07-26': 1131,
#  '2021-07-27': 1147,
#  '2021-07-28': 1071,
#  '2021-07-29': 1081,
#  '2021-07-30': 1031,
#  '2021-07-31': 1015,
#  '2021-08-01': 1055,
#  '2021-08-02': 1107,
#  '2021-08-03': 1128,
#  '2021-08-04': 1153,
#  '2021-08-05': 1063,
#  '2021-08-06': 1037,
#  '2021-08-07': 1072,
#  '2021-08-08': 1083,
#  '2021-08-09': 1195,
#  '2021-08-10': 1214,
#  '2021-08-11': 1190,
#  '2021-08-12': 1175,
#  '2021-08-13': 1116,
#  '2021-08-14': 1047,
#  '2021-08-15': 1047,
#  '2021-08-16': 1200,
#  '2021-08-17': 1160,
#  '2021-08-18': 1162,
#  '2021-08-19': 1256,
#  '2021-08-20': 1137,
#  '2021-08-21': 1099,
#  '2021-08-22': 1164,
#  '2021-08-23': 1152,
#  '2021-08-24': 1210,
#  '2021-08-25': 1122,
#  '2021-08-26': 1130,
#  '2021-08-27': 1079,
#  '2021-08-28': 1058,
#  '2021-08-29': 1046,
#  '2021-08-30': 1129,
#  '2021-08-31': 1114,
#  '2021-09-01': 1062,
#  '2021-09-02': 1041,
#  '2021-09-03': 1073,
#  '2021-09-04': 1003,
#  '2021-09-05': 1081,
#  '2021-09-06': 1218,
#  '2021-09-07': 1168,
#  '2021-09-08': 1122,
#  '2021-09-09': 1174,
#  '2021-09-10': 1167,
#  '2021-09-11': 1051,
#  '2021-09-12': 1016,
#  '2021-09-13': 1206,
#  '2021-09-14': 1203,
#  '2021-09-15': 1186,
#  '2021-09-16': 1189,
#  '2021-09-17': 1155,
#  '2021-09-18': 1015,
#  '2021-09-19': 1081,
#  '2021-09-20': 1165,
#  '2021-09-21': 1173,
#  '2021-09-22': 1102,
#  '2021-09-23': 1123,
#  ...}

# %% [markdown]
# We have the page name, the total number of page views for the selected period, the average number of views per day and the number of page views for each day of the period. Let's make one table for all data in which there will be 6 columns:
#
# [PageName, Date, PageViews, Month, Year ,Month/Year]
#
# Fortunately, there are no missing values in this dataset, but there are some outliers. To cope with these outliers, we will use an interquartile range approach. Define as
#
# Q1 = PageViews.quantile(0.25), Q3 = PageViews.quantile(0.75), IQR = Q3 - Q1.
# We will delete all values that are not in range:
#
# [Q1 - 1.5 * IQR; Q3 + 1.5 * IQR]

# %%
diseases_names = ['anxiety_en', 'depression_en', 'insomnia_en', 'loneliness_en', 'stress_en']

def get_data():
    # create DataFrame
    df = pd.DataFrame({'PageName' :[], 'Date':[], 'PageViews':[]}) 
    for disease in diseases_names:
        # read files
        with open('./data/{}.json'.format(disease), 'r') as file: 
            data = json.load(file)[0]
            # add data to DataFrame
            df = pd.concat([df, pd.DataFrame({'PageName' :[disease]*(len(data)-3), 'Date':list(data.keys())[3:],
                                         'PageViews':list(data.values())[3:]})])
    
    # add month, year, month/year columns
    df['Month'] = df['Date'].apply(lambda x: x[5:7])
    df['Year'] = df['Date'].apply(lambda x: x[0:4])
    df['Month/Year'] = df['Date'].apply(lambda x:  x[5:7] + '/' + x[0:4])
    
    # interquartile range approach for deleting outliers
    Q1 = df['PageViews'].quantile(0.25)
    Q3 = df['PageViews'].quantile(0.75)
    IQR = Q3 - Q1    

    df = df[(df['PageViews'] >= Q1 - 1.5 * IQR) & (df['PageViews'] <= Q3 + 1.5 *IQR)] 
    
    return df

# %%
df = get_data()
df.head()
# Out:
#      PageName        Date  PageViews Month  Year Month/Year
# 0  anxiety_en  2019-01-01     1486.0    01  2019    01/2019
# 1  anxiety_en  2019-01-02     1842.0    01  2019    01/2019
# 2  anxiety_en  2019-01-03     1715.0    01  2019    01/2019
# 3  anxiety_en  2019-01-04     1724.0    01  2019    01/2019
# 4  anxiety_en  2019-01-05     1872.0    01  2019    01/2019

# %%
def plot_separetely(df, date_type, page_name, year, show_outliers=False):
    sns.set(rc={'figure.figsize':(12,8)})
    plt.title('Monthly statistics of page views about {} in {}'.format(page_name, year))
    
    if date_type == 'Month':
        data = df[(df['Year'] == '{}'.format(year)) & (df['PageName'] == page_name)]
    else:
        data = df[df['PageName'] == page_name]
        
    ax = sns.boxplot(x=date_type, y="PageViews", data=data,
                        showmeans=True, showfliers=show_outliers)
    ax = sns.pointplot(x=date_type, y="PageViews", data=data,
                       errorbar=None, color='black')

# %%
plot_separetely(df, 'Month/Year', 'depression_en', '2019-2021', True)

# %%
plot_separetely(df, 'Month', 'depression_en', 2020, True)

# %%
def plot_compare(df, page_name=None, year=None, errorbar='sd'):
    if year is not None:
        plt.title('Monthly PageView statistics in {} by topics'.format(year))
        ax = sns.lineplot(x="Month", y="PageViews", data=df[df['Year'] == '{}'.format(year)], errorbar=errorbar, hue="PageName")
    if page_name is not None:
        plt.title('Monthly statistics of page views about {} by years'.format(page_name))
        ax = sns.lineplot(x="Month", y="PageViews", data=df[df['PageName'] == page_name], errorbar=errorbar, hue="Year")

# %%
plot_compare(df, year=2020)

# %%
plot_compare(df, page_name='depression_en')

# %%
def cohen_d(sample_A, sample_B):
    '''
     Compute cohen's d value for independent values
     :param sample_A and sample_B: pd.DataFrame
     :return: d
     '''
    diff_mean = np.abs(np.mean(sample_A) - np.mean(sample_B))
    nb_A = len(sample_A)
    nb_B = len(sample_B)
    A_sd = np.std(sample_A)
    B_sd = np.std(sample_B)
    
    pooled_sd = np.sqrt(((nb_A-1) * A_sd**2 + (nb_B-1) * B_sd**2)/(nb_A + nb_B -2))
    
    d = diff_mean/pooled_sd
    
    print('Cohen s d effect size value is d = ' + str(d) 
      + ' with the sample size n = ' + str(len(sample_A)))
    
    return d

def test_pageviews_means(page_name):
    depression_2019 = df[(df['Year'] == '2019') & (df['PageName'] == page_name)]['PageViews'].to_list()
    depression_2020 = df[(df['Year'] == '2020') & (df['PageName'] == page_name)]['PageViews'].to_list()
    depression_2021 = df[(df['Year'] == '2021') & (df['PageName'] == page_name)]['PageViews'].to_list()
    
    mean_2019 = np.mean(depression_2019)
    mean_2020 = np.mean(depression_2020)
    mean_2021 = np.mean(depression_2021)
    
    tvalue1, pvalue1 = stats.ttest_ind(depression_2019, depression_2020, equal_var= True)
    tvalue2, pvalue2 = stats.ttest_ind(depression_2020, depression_2021, equal_var= True)
    
    print('Pvalue of the sample t-test for the pageviews statistic about {} in 2019 and 2020: \n {}\n'.format(page_name, pvalue1))
    cohen_d(depression_2019, depression_2020)
    print('\nPageviews mean for 2019 and 2020 and their difference: \n {}, {}, {}'.format(mean_2019, mean_2020, mean_2019-mean_2020))
    print('----------------------------------------------------------------')
    print('Pvalue of the sample t-test for the pageviews statistic about {} in 2020 and 2021:\n {}\n'.format(page_name, pvalue2))
    cohen_d(depression_2020, depression_2021)
    print('\nPageviews mean for 2020 and 2021 and their difference: \n  {}, {}, {}'.format(mean_2020, mean_2021, mean_2020-mean_2021))

# %%
test_pageviews_means('depression_en')
# Out:
# Pvalue of the sample t-test for the pageviews statistic about depression_en in 2019 and 2020:
#  0.3664959830447566
#
# Cohen s d effect size value is d = 0.06711991822032258 with the sample size n = 365
#
# Pageviews mean for 2019 and 2020 and their difference:
#  1784.731506849315, 1799.7845303867402, -15.053023537425133
# ----------------------------------------------------------------
# Pvalue of the sample t-test for the pageviews statistic about depression_en in 2020 and 2021:
#  1.8919218606161319e-19
#
# Cohen s d effect size value is d = 0.6894364266588466 with the sample size n = 362
#
# Pageviews mean for 2020 and 2021 and their difference:
#   1799.7845303867402, 1663.0438356164384, 136.74069477030184
